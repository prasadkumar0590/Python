# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import difflib
with open('/content/sample_data/file1.txt') as f1:
    line1 = f1.readline()
with open('/content/sample_data/file2.txt') as f2:
    line2 = f2.readline()
# Find and print the diff:
count=1
while line1 and line2:
  if line != line2:
    for i,x in enumerate(line1):
      if x != line2[i]:
        print(count,line1[i,-2],line2[i,-2])
      count+=1
      line1 = f1.readline()
      line2 = f2.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-d3227e0a4730> in <module>()
#      12         print(count,line1[i,-2],line2[i,-2])
#      13       count+=1
# ---> 14       line1 = f1.readline()
#      15       line2 = f2.readline()
#      16
#
# ValueError: I/O operation on closed file.
